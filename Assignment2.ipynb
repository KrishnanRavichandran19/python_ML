# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
titanic_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/First_ML_Model/master/titanic.csv", index_col = 'PassengerId')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
titanic_data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_data.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
titanic_data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
np.mean(titanic_data['Survived'])
# Out:
# 0.3838383838383838

# %%
np.median(titanic_data["Fare"])
# Out:
# 14.4542

# %%
np.mean(titanic_data['Survived'][titanic_data['Age'] <= 18])
# Out:
# 0.5035971223021583

# %%
subset_titanic = (titanic_data['Survived'] == 1)

# %%
subset_titanic.head()
# Out:
# PassengerId
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Survived, dtype: bool

# %%
titanic_data.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
np.mean(titanic_data['Survived'][titanic_data['Embarked'] == 'Q'])
# Out:
# 0.38961038961038963

# %%
subset = titanic_data[['Survived' == 1]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-6292e3c609b6> in <module>()
# ----> 1 subset = titanic_data[['Survived' == 1]]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2836         elif len(key) != len(self.index):
#    2837             raise ValueError(
# -> 2838                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2839             )
#    2840
#
# ValueError: Item wrong length 1 instead of 891.

# %%
titanic_data.Fare.sort_values()
# Out:
# PassengerId
# 272      0.0000
# 598      0.0000
# 303      0.0000
# 634      0.0000
# 278      0.0000
#          ...
# 439    263.0000
# 342    263.0000
# 738    512.3292
# 259    512.3292
# 680    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
titanic_data.Age.median()
# Out:
# 28.0

# %%
titanic_data.Name.value_counts()
# Out:
# Lovell, Mr. John Hall ("Henry")                1
# Blackwell, Mr. Stephen Weart                   1
# Marechal, Mr. Pierre                           1
# Lundahl, Mr. Johan Svensson                    1
# Daniel, Mr. Robert Williams                    1
#                                               ..
# Hart, Mrs. Benjamin (Esther Ada Bloomfield)    1
# Vovk, Mr. Janko                                1
# Johnson, Miss. Eleanor Ileen                   1
# Hocking, Mrs. Elizabeth (Eliza Needs)          1
# McCoy, Mr. Bernard                             1
# Name: Name, Length: 891, dtype: int64
